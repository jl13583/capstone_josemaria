# %%
print(version())
# Out:
# SageMath version 10.7, Release Date: 2025-08-09
# /var/folders/db/kjkgjcbj5619ftndd0m2xsyr0000gn/T/ipykernel_9003/581065667.py:1: DeprecationWarning: Use sage.version instead.
# See https://github.com/sagemath/sage/issues/39015 for details.
#   print(version())
